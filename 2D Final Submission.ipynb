# %% [markdown]
# # 2D Data Driven World Assignment

# %% [markdown]
# ## ● Names of the group members.
#
#
# Aravind Gopinath Nair– 1006057
#
# Toh Hengyi Lucas – 1006061
#
# Ang Yue Sheng – 1005964
#
# Lim Yong Qing – 1005955
#
# Rishika Banka – 1006304

# %% [markdown]
# ## ● Problem Statement
#
# ### o Background description of the problem
#
# The United Nation and World Health Organization is forming a common taskforce together with industry leaders to address issues related to food security and safety. Such organisations require data-driven modelling to help them identify key factors to target to effectively solve the challenges in this area.
#
# According to WHO, poor sanitation is thought to be the main factor in some 432 000 of total diarrhoeal deaths. Furthermore, sanitation is a major factor in several neglected food-related tropical diseases, such as intestinal worms and parisitic worm disease of the gut. Furthermore, poor sanitation has an effect on malnutrition in a country.
#
# ### o User Personas
#
# - International Organisations (IGO)
# IGOs such as the United Nations are organisations that are involved in global affairs. Such IGOs are in contact with industry leaders that are profit-driven, whose decisions are based on empirical data. With the data from countries provided, IGOs are more able to convince industry leaders and other world leaders to provide aid to countries in need.
#
#
# - Non-profit Organisations
# NPOs are involved in humanitarian and social services to provide foreign aid to countries in need. These organisations are not profit-driven, and as such, they would have fewer resources to hire a data team to analyse the countries of which they are helping to make more optimal decisions. These organisations would greatly benefit from having free public access data that enables them to optimise the usage of their resources.
#
#
# - Policymakers
# Within a country itself, there are policymakers that have a heavy influence over the lives of the people in the country through the laws they enforce. With data, policymakers are empowered to bring their policies into action with less delay. Through such policies, the country's standards of living would improve by enabling them to enact policies of successful nations and avoiding policies that are proven to be ineffective. As such, the standard of living in the country would be improved with less reliance on foreign aid.
#
#
#
# ### o Problem Statement using “how might we ...” statement
#
# How might we predict food safety in terms of the percentage of people with access to a basic level of sanitation in different countries by first identifying the most important and independent socio-economic factors and using them as inputs into a multilinear regression model?

# %% [markdown]
# ## ● Data
#
# ### o Link to data sources
#
# ###### WHO Sanitation :
#
# https://www.who.int/news-room/fact-sheets/detail/sanitation
#
#
#
#
# ##### Datasets used :
#
# https://databank.worldbank.org/source/world-development-indicators
#
# Filters used for above : World Development Indicators | Low and Low-middle Income Countries | 2014-2016
#
#
#
# ###### Credibility of Data Source Worldbank :
#
# https://www.theguardian.com/global-development-professionals-network/2016/mar/16/the-top-10-sources-of-data-for-international-development-research
#
#
# Definition of correlation coefficient r : https://corporatefinanceinstitute.com/resources/data-science/correlation/
#
#
# ### o Discussion on why these data were used, including any relevant visualizations
# Firstly, the data from Worldbank is credible according the TheGuardian.
# Secondly, the data was more convenient to use as compared to FAO and Kaggle as all the data has a standardised csv format with fewer columns that are not relevant.
# Thirdly, the data from Worldbank included socio-economic features as well as food security target csv data relevant to our project.
#
# To be specific about our data, we only chose countries in the low to lower middle income range for Years 2014 to 2016, which has the advantage of ensuring that the usage of median to fill in the NaN values is more effective when processing the data.
#
# ### o Code and steps to clean the data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Functions used to clean the data

# Extracts only relevant data columns from DataFrame which is only the Country Name, Feature Name, Value of Feature of one year
def select_year(dfin): 
    df = dfin.replace("..", np.nan)
    df = df[["Series Name","Country Name",dfin.columns[4]]]
    year = df.columns[2].rsplit()
    year = str(year[0])
    df[df.columns[1]] = df["Country Name"] + year
    df_out =df
    return df_out

# Creates new column : '(Country)+(Year)' to be used as index for each row of data in a DataFrame
def arrange_data(dfin): 
    country_dc = {}
    for country in dfin["Country Name"]:
            if country not in country_dc:
                    country_dc[country] = {}
                    
    for index,row in dfin.iterrows():
            country_dc[row[1]][row[0]]= row[2]
    return pd.DataFrame.from_dict(country_dc).T

# Calculates of mean of data of each column in a DataFrame and removes all data outside n_std standard deviations from mean
def remove_outliers(df,columns,n_std):
    for col in columns:
        mean = df[col].mean()
        sd = df[col].std()
        
        df = df[(df[col] <= mean+(n_std*sd))]
        
    return df

# r value here is to calculate correlation coefficient between 2 columns in a DataFrame.
def r_value(dfin,features_ls,target_ls):
    r_val_dict = {}
    for col in target_ls:
        r_val_dict[col] = {}
        for row in features_ls:
            
            feature1 = dfin[col]
            feature2 = dfin[row]
            
            feature1_mean = dfin[col].mean()
            feature2_mean = dfin[row].mean()
            
            feature1_diff = feature1 -feature1_mean
            feature2_diff = feature2 -feature2_mean
            
            numerator = (feature1_diff*feature2_diff).sum()
            denominator = np.sqrt((feature1_diff**2).sum()*(feature2_diff**2).sum())
            r_val = (numerator/denominator)
            r_val_dict[col][row] = r_val
    
    return pd.DataFrame(r_val_dict).T
            
# nan_percent =  threshold percentage of values in the column that is NaN
# Removes columns which have reach the threshold indicated (i.e removing features that have insufficient data)
def drop_cols(dfin,nan_percent = 0.05):
    dfout = pd.DataFrame(dfin)
    for (colname,colval) in dfin.items():
        nan_no = np.count_nonzero(np.isnan(colval.values))
        total_no = np.count_nonzero(colval.values)
        if (nan_no/total_no) >=nan_percent:
            dfout = dfout.drop(colname,axis=1)
    return dfout

# Inputs DataFrame and target(String) and returns a list of the target and features
def seperate_target_out(dfin,target):
    features_ls = list(dfin.columns)
    features_ls.remove(target)
    target_ls = [target]
    return target_ls, features_ls

# Replace NaN values in each column of the whole DataFrame with the median of each column
def add_median(dfin):
    data = []
    for column in dfin.columns:
        median = dfin[column].median()
        data.append(dfin[column].replace(np.nan,median))
    dfout =pd.concat(data,axis =1)
    return dfout

# r2 = r_value ** 2 (square of correlation coefficient)
# Using calculated r2 values of all features against the target, returns features that r2 value that is above the r2_threshold
def find_related_features(dfin,r2_threshold):
    column_name = dfin.columns[0]
    dfout = dfin[dfin[column_name]>= r2_threshold]
    return dfout

# %%
# Loading Data In
df_2014 = pd.read_csv("Raw Data/2014 Data.csv")
df_2015 = pd.read_csv("Raw Data/2015 Data.csv")
df_2016 = pd.read_csv("Raw Data/2016 Data.csv")

# Removing '..' values that represent no data in rows with NaN
df_2014 = df_2014.replace("..", np.nan)
df_2015 = df_2015.replace("..", np.nan)
df_2016 = df_2016.replace("..", np.nan)

# %%
# Combining Years 2014, 2015 and 2016 data to one CSV
df_2014_clean = select_year(df_2014)
df_2014_clean = arrange_data(df_2014_clean)

df_2015_clean = select_year(df_2015)
df_2015_clean = arrange_data(df_2015_clean)

df_2016_clean = select_year(df_2016)
df_2016_clean = arrange_data(df_2016_clean)

data = [df_2014_clean,df_2015_clean,df_2016_clean]
df_data = pd.concat(data).astype(float)
df_data.to_csv("Processed Data/Combined Data.csv")

df_col_dropped = drop_cols(df_data,nan_percent = 0.6) # Dropping features with >60% NaN values
display(df_col_dropped)
df_col_dropped.to_csv("Processed Data/Dropped.csv")
# Out:
#                         Adjusted net enrollment rate, primary (% of primary school age children)  \
# Afghanistan2014                                                       NaN
# Algeria2014                                                           NaN
# Angola2014                                                            NaN
# Bangladesh2014                                                        NaN
# Benin2014                                                        96.36058
# ...                                                                   ...
# Vietnam2016                                                           NaN
# West Bank and Gaza2016                                           95.77247
# Yemen, Rep.2016                                                  84.39664
# Zambia2016                                                            NaN
# Zimbabwe2016                                                          NaN
#
#                         Adjusted net enrollment rate, primary, female (% of primary school age children)  \
# Afghanistan2014                                                       NaN
# Algeria2014                                                           NaN
# Angola2014                                                            NaN
# Bangladesh2014                                                        NaN
# Benin2014                                                             NaN
# ...                                                                   ...
# Vietnam2016                                                           NaN
# West Bank and Gaza2016                                           96.25543
# Yemen, Rep.2016                                                  78.87941
# Zambia2016                                                            NaN
# Zimbabwe2016                                                          NaN
#
#                         Adjusted net enrollment rate, primary, male (% of primary school age children)  \
# Afghanistan2014                                                       NaN
# Algeria2014                                                           NaN
# Angola2014                                                            NaN
# Bangladesh2014                                                        NaN
# Benin2014                                                             NaN
# ...                                                                   ...
# Vietnam2016                                                           NaN
# West Bank and Gaza2016                                            95.3098
# Yemen, Rep.2016                                                   89.7010
# Zambia2016                                                            NaN
# Zimbabwe2016                                                          NaN
#
#                         Adolescents out of school (% of lower secondary school age)  \
# Afghanistan2014                                                       NaN
# Algeria2014                                                           NaN
# Angola2014                                                            NaN
# Bangladesh2014                                                   39.78434
# Benin2014                                                             NaN
# ...                                                                   ...
# Vietnam2016                                                           NaN
# West Bank and Gaza2016                                            7.35438
# Yemen, Rep.2016                                                  28.44315
# Zambia2016                                                            NaN
# Zimbabwe2016                                                      2.26147
#
#                         Adolescents out of school, female (% of female lower secondary school age)  \
# Afghanistan2014                                                       NaN
# Algeria2014                                                           NaN
# Angola2014                                                            NaN
# Bangladesh2014                                                  33.550812
# Benin2014                                                             NaN
# ...                                                                   ...
# Vietnam2016                                                           NaN
# West Bank and Gaza2016                                           5.404580
# Yemen, Rep.2016                                                 34.475868
# Zambia2016                                                            NaN
# Zimbabwe2016                                                          NaN
#
#                         Adolescents out of school, male (% of male lower secondary school age)  \
# Afghanistan2014                                                       NaN
# Algeria2014                                                           NaN
# Angola2014                                                            NaN
# Bangladesh2014                                                  45.761269
# Benin2014                                                             NaN
# ...                                                                   ...
# Vietnam2016                                                           NaN
# West Bank and Gaza2016                                           9.226390
# Yemen, Rep.2016                                                 22.633860
# Zambia2016                                                            NaN
# Zimbabwe2016                                                          NaN
#
#                         Age dependency ratio (% of working-age population)  \
# Afghanistan2014                                                 92.649143
# Algeria2014                                                     51.509189
# Angola2014                                                      97.942205
# Bangladesh2014                                                  53.578668
# Benin2014                                                       86.811436
# ...                                                                   ...
# Vietnam2016                                                     42.575372
# West Bank and Gaza2016                                          74.344664
# Yemen, Rep.2016                                                 76.024870
# Zambia2016                                                      91.971859
# Zimbabwe2016                                                    83.576729
#
#                         Age dependency ratio, old (% of working-age population)  \
# Afghanistan2014                                                  4.722937
# Algeria2014                                                      8.686205
# Angola2014                                                       4.558697
# Bangladesh2014                                                   7.792943
# Benin2014                                                        6.030833
# ...                                                                   ...
# Vietnam2016                                                      9.730330
# West Bank and Gaza2016                                           5.326847
# Yemen, Rep.2016                                                  4.973850
# Zambia2016                                                       3.975174
# Zimbabwe2016                                                     5.253557
#
#                         Age dependency ratio, young (% of working-age population)  \
# Afghanistan2014                                                 87.926206
# Algeria2014                                                     42.822985
# Angola2014                                                      93.383508
# Bangladesh2014                                                  45.785724
# Benin2014                                                       80.780603
# ...                                                                   ...
# Vietnam2016                                                     32.845043
# West Bank and Gaza2016                                          69.017817
# Yemen, Rep.2016                                                 71.051020
# Zambia2016                                                      87.996686
# Zimbabwe2016                                                    78.323172
#
#                         Antiretroviral therapy coverage (% of people living with HIV)  \
# Afghanistan2014                                                       4.0
# Algeria2014                                                          62.0
# Angola2014                                                           22.0
# Bangladesh2014                                                       13.0
# Benin2014                                                            41.0
# ...                                                                   ...
# Vietnam2016                                                          53.0
# West Bank and Gaza2016                                                NaN
# Yemen, Rep.2016                                                      24.0
# Zambia2016                                                           65.0
# Zimbabwe2016                                                         70.0
#
#                         ...  Trade (% of GDP)  \
# Afghanistan2014         ...               NaN
# Algeria2014             ...         62.414316
# Angola2014              ...         79.332923
# Bangladesh2014          ...         44.514080
# Benin2014               ...         65.268275
# ...                     ...               ...
# Vietnam2016             ...               NaN
# West Bank and Gaza2016  ...         65.422514
# Yemen, Rep.2016         ...         25.276643
# Zambia2016              ...         73.958561
# Zimbabwe2016            ...         51.219025
#
#                         Unemployment, female (% of female labor force) (modeled ILO estimate)  \
# Afghanistan2014                                                 14.152000
# Algeria2014                                                     15.581000
# Angola2014                                                       7.754000
# Bangladesh2014                                                   7.482000
# Benin2014                                                        2.366000
# ...                                                                   ...
# Vietnam2016                                                      1.699000
# West Bank and Gaza2016                                          37.952999
# Yemen, Rep.2016                                                 25.850000
# Zambia2016                                                      11.667000
# Zimbabwe2016                                                     5.191000
#
#                         Unemployment, female (% of female labor force) (national estimate)  \
# Afghanistan2014                                                 10.110000
# Algeria2014                                                     15.580000
# Angola2014                                                       9.100000
# Bangladesh2014                                                        NaN
# Benin2014                                                             NaN
# ...                                                                   ...
# Vietnam2016                                                      1.700000
# West Bank and Gaza2016                                          37.970001
# Yemen, Rep.2016                                                       NaN
# Zambia2016                                                            NaN
# Zimbabwe2016                                                          NaN
#
#                         Unemployment, male (% of male labor force) (modeled ILO estimate)  \
# Afghanistan2014                                                 10.469000
# Algeria2014                                                      8.961000
# Angola2014                                                       6.999000
# Bangladesh2014                                                   3.174000
# Benin2014                                                        1.906000
# ...                                                                   ...
# Vietnam2016                                                      1.989000
# West Bank and Gaza2016                                          20.570999
# Yemen, Rep.2016                                                 12.311000
# Zambia2016                                                      10.139000
# Zimbabwe2016                                                     4.358000
#
#                         Unemployment, male (% of male labor force) (national estimate)  \
# Afghanistan2014                                                      7.20
# Algeria2014                                                          8.96
# Angola2014                                                           9.96
# Bangladesh2014                                                        NaN
# Benin2014                                                             NaN
# ...                                                                   ...
# Vietnam2016                                                          1.99
# West Bank and Gaza2016                                              20.58
# Yemen, Rep.2016                                                       NaN
# Zambia2016                                                            NaN
# Zimbabwe2016                                                          NaN
#
#                         Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# Afghanistan2014                                                 11.142000
# Algeria2014                                                     10.210000
# Angola2014                                                       7.372000
# Bangladesh2014                                                   4.384000
# Benin2014                                                        2.133000
# ...                                                                   ...
# Vietnam2016                                                      1.850000
# West Bank and Gaza2016                                          23.940001
# Yemen, Rep.2016                                                 13.433000
# Zambia2016                                                      10.872000
# Zimbabwe2016                                                     4.788000
#
#                         Unemployment, total (% of total labor force) (national estimate)  \
# Afghanistan2014                                                  7.910000
# Algeria2014                                                     10.210000
# Angola2014                                                       9.580000
# Bangladesh2014                                                        NaN
# Benin2014                                                             NaN
# ...                                                                   ...
# Vietnam2016                                                      1.850000
# West Bank and Gaza2016                                          23.940001
# Yemen, Rep.2016                                                       NaN
# Zambia2016                                                            NaN
# Zimbabwe2016                                                          NaN
#
#                         Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate)  \
# Afghanistan2014                                                 21.681000
# Algeria2014                                                     40.507000
# Angola2014                                                      16.697001
# Bangladesh2014                                                  11.744000
# Benin2014                                                        5.078000
# ...                                                                   ...
# Vietnam2016                                                      6.734000
# West Bank and Gaza2016                                          60.449001
# Yemen, Rep.2016                                                 34.591000
# Zambia2016                                                      21.313999
# Zimbabwe2016                                                     7.784000
#
#                         Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate)  \
# Afghanistan2014                                                 16.518000
# Algeria2014                                                     22.832001
# Angola2014                                                      16.764000
# Bangladesh2014                                                   9.814000
# Benin2014                                                        4.163000
# ...                                                                   ...
# Vietnam2016                                                      6.763000
# West Bank and Gaza2016                                          33.678001
# Yemen, Rep.2016                                                 23.622000
# Zambia2016                                                      19.726999
# Zimbabwe2016                                                     5.927000
#
#                         Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate)
# Afghanistan2014                                                 17.570000
# Algeria2014                                                     25.559000
# Angola2014                                                      16.731001
# Bangladesh2014                                                  10.363000
# Benin2014                                                        4.664000
# ...                                                                   ...
# Vietnam2016                                                      6.750000
# West Bank and Gaza2016                                          38.237000
# Yemen, Rep.2016                                                 24.660999
# Zambia2016                                                      20.513000
# Zimbabwe2016                                                     6.825000
#
# [246 rows x 239 columns]

# %%
# Replaces NaN values with the median of the column
df_median_filled = add_median(df_col_dropped)
display(df_median_filled)
# Out:
#                         Adjusted net enrollment rate, primary (% of primary school age children)  \
# Afghanistan2014                                                  90.02310
# Algeria2014                                                      90.02310
# Angola2014                                                       90.02310
# Bangladesh2014                                                   90.02310
# Benin2014                                                        96.36058
# ...                                                                   ...
# Vietnam2016                                                      90.02310
# West Bank and Gaza2016                                           95.77247
# Yemen, Rep.2016                                                  84.39664
# Zambia2016                                                       90.02310
# Zimbabwe2016                                                     90.02310
#
#                         Adjusted net enrollment rate, primary, female (% of primary school age children)  \
# Afghanistan2014                                                  85.70568
# Algeria2014                                                      85.70568
# Angola2014                                                       85.70568
# Bangladesh2014                                                   85.70568
# Benin2014                                                        85.70568
# ...                                                                   ...
# Vietnam2016                                                      85.70568
# West Bank and Gaza2016                                           96.25543
# Yemen, Rep.2016                                                  78.87941
# Zambia2016                                                       85.70568
# Zimbabwe2016                                                     85.70568
#
#                         Adjusted net enrollment rate, primary, male (% of primary school age children)  \
# Afghanistan2014                                                  88.30147
# Algeria2014                                                      88.30147
# Angola2014                                                       88.30147
# Bangladesh2014                                                   88.30147
# Benin2014                                                        88.30147
# ...                                                                   ...
# Vietnam2016                                                      88.30147
# West Bank and Gaza2016                                           95.30980
# Yemen, Rep.2016                                                  89.70100
# Zambia2016                                                       88.30147
# Zimbabwe2016                                                     88.30147
#
#                         Adolescents out of school (% of lower secondary school age)  \
# Afghanistan2014                                                 19.433929
# Algeria2014                                                     19.433929
# Angola2014                                                      19.433929
# Bangladesh2014                                                  39.784340
# Benin2014                                                       19.433929
# ...                                                                   ...
# Vietnam2016                                                     19.433929
# West Bank and Gaza2016                                           7.354380
# Yemen, Rep.2016                                                 28.443150
# Zambia2016                                                      19.433929
# Zimbabwe2016                                                     2.261470
#
#                         Adolescents out of school, female (% of female lower secondary school age)  \
# Afghanistan2014                                                 23.988251
# Algeria2014                                                     23.988251
# Angola2014                                                      23.988251
# Bangladesh2014                                                  33.550812
# Benin2014                                                       23.988251
# ...                                                                   ...
# Vietnam2016                                                     23.988251
# West Bank and Gaza2016                                           5.404580
# Yemen, Rep.2016                                                 34.475868
# Zambia2016                                                      23.988251
# Zimbabwe2016                                                    23.988251
#
#                         Adolescents out of school, male (% of male lower secondary school age)  \
# Afghanistan2014                                                 22.195431
# Algeria2014                                                     22.195431
# Angola2014                                                      22.195431
# Bangladesh2014                                                  45.761269
# Benin2014                                                       22.195431
# ...                                                                   ...
# Vietnam2016                                                     22.195431
# West Bank and Gaza2016                                           9.226390
# Yemen, Rep.2016                                                 22.633860
# Zambia2016                                                      22.195431
# Zimbabwe2016                                                    22.195431
#
#                         Age dependency ratio (% of working-age population)  \
# Afghanistan2014                                                 92.649143
# Algeria2014                                                     51.509189
# Angola2014                                                      97.942205
# Bangladesh2014                                                  53.578668
# Benin2014                                                       86.811436
# ...                                                                   ...
# Vietnam2016                                                     42.575372
# West Bank and Gaza2016                                          74.344664
# Yemen, Rep.2016                                                 76.024870
# Zambia2016                                                      91.971859
# Zimbabwe2016                                                    83.576729
#
#                         Age dependency ratio, old (% of working-age population)  \
# Afghanistan2014                                                  4.722937
# Algeria2014                                                      8.686205
# Angola2014                                                       4.558697
# Bangladesh2014                                                   7.792943
# Benin2014                                                        6.030833
# ...                                                                   ...
# Vietnam2016                                                      9.730330
# West Bank and Gaza2016                                           5.326847
# Yemen, Rep.2016                                                  4.973850
# Zambia2016                                                       3.975174
# Zimbabwe2016                                                     5.253557
#
#                         Age dependency ratio, young (% of working-age population)  \
# Afghanistan2014                                                 87.926206
# Algeria2014                                                     42.822985
# Angola2014                                                      93.383508
# Bangladesh2014                                                  45.785724
# Benin2014                                                       80.780603
# ...                                                                   ...
# Vietnam2016                                                     32.845043
# West Bank and Gaza2016                                          69.017817
# Yemen, Rep.2016                                                 71.051020
# Zambia2016                                                      87.996686
# Zimbabwe2016                                                    78.323172
#
#                         Antiretroviral therapy coverage (% of people living with HIV)  \
# Afghanistan2014                                                       4.0
# Algeria2014                                                          62.0
# Angola2014                                                           22.0
# Bangladesh2014                                                       13.0
# Benin2014                                                            41.0
# ...                                                                   ...
# Vietnam2016                                                          53.0
# West Bank and Gaza2016                                               33.0
# Yemen, Rep.2016                                                      24.0
# Zambia2016                                                           65.0
# Zimbabwe2016                                                         70.0
#
#                         ...  Trade (% of GDP)  \
# Afghanistan2014         ...         61.969432
# Algeria2014             ...         62.414316
# Angola2014              ...         79.332923
# Bangladesh2014          ...         44.514080
# Benin2014               ...         65.268275
# ...                     ...               ...
# Vietnam2016             ...         61.969432
# West Bank and Gaza2016  ...         65.422514
# Yemen, Rep.2016         ...         25.276643
# Zambia2016              ...         73.958561
# Zimbabwe2016            ...         51.219025
#
#                         Unemployment, female (% of female labor force) (modeled ILO estimate)  \
# Afghanistan2014                                                 14.152000
# Algeria2014                                                     15.581000
# Angola2014                                                       7.754000
# Bangladesh2014                                                   7.482000
# Benin2014                                                        2.366000
# ...                                                                   ...
# Vietnam2016                                                      1.699000
# West Bank and Gaza2016                                          37.952999
# Yemen, Rep.2016                                                 25.850000
# Zambia2016                                                      11.667000
# Zimbabwe2016                                                     5.191000
#
#                         Unemployment, female (% of female labor force) (national estimate)  \
# Afghanistan2014                                                 10.110000
# Algeria2014                                                     15.580000
# Angola2014                                                       9.100000
# Bangladesh2014                                                   5.610000
# Benin2014                                                        5.610000
# ...                                                                   ...
# Vietnam2016                                                      1.700000
# West Bank and Gaza2016                                          37.970001
# Yemen, Rep.2016                                                  5.610000
# Zambia2016                                                       5.610000
# Zimbabwe2016                                                     5.610000
#
#                         Unemployment, male (% of male labor force) (modeled ILO estimate)  \
# Afghanistan2014                                                 10.469000
# Algeria2014                                                      8.961000
# Angola2014                                                       6.999000
# Bangladesh2014                                                   3.174000
# Benin2014                                                        1.906000
# ...                                                                   ...
# Vietnam2016                                                      1.989000
# West Bank and Gaza2016                                          20.570999
# Yemen, Rep.2016                                                 12.311000
# Zambia2016                                                      10.139000
# Zimbabwe2016                                                     4.358000
#
#                         Unemployment, male (% of male labor force) (national estimate)  \
# Afghanistan2014                                                      7.20
# Algeria2014                                                          8.96
# Angola2014                                                           9.96
# Bangladesh2014                                                       4.83
# Benin2014                                                            4.83
# ...                                                                   ...
# Vietnam2016                                                          1.99
# West Bank and Gaza2016                                              20.58
# Yemen, Rep.2016                                                      4.83
# Zambia2016                                                           4.83
# Zimbabwe2016                                                         4.83
#
#                         Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# Afghanistan2014                                                 11.142000
# Algeria2014                                                     10.210000
# Angola2014                                                       7.372000
# Bangladesh2014                                                   4.384000
# Benin2014                                                        2.133000
# ...                                                                   ...
# Vietnam2016                                                      1.850000
# West Bank and Gaza2016                                          23.940001
# Yemen, Rep.2016                                                 13.433000
# Zambia2016                                                      10.872000
# Zimbabwe2016                                                     4.788000
#
#                         Unemployment, total (% of total labor force) (national estimate)  \
# Afghanistan2014                                                  7.910000
# Algeria2014                                                     10.210000
# Angola2014                                                       9.580000
# Bangladesh2014                                                   4.770000
# Benin2014                                                        4.770000
# ...                                                                   ...
# Vietnam2016                                                      1.850000
# West Bank and Gaza2016                                          23.940001
# Yemen, Rep.2016                                                  4.770000
# Zambia2016                                                       4.770000
# Zimbabwe2016                                                     4.770000
#
#                         Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate)  \
# Afghanistan2014                                                 21.681000
# Algeria2014                                                     40.507000
# Angola2014                                                      16.697001
# Bangladesh2014                                                  11.744000
# Benin2014                                                        5.078000
# ...                                                                   ...
# Vietnam2016                                                      6.734000
# West Bank and Gaza2016                                          60.449001
# Yemen, Rep.2016                                                 34.591000
# Zambia2016                                                      21.313999
# Zimbabwe2016                                                     7.784000
#
#                         Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate)  \
# Afghanistan2014                                                 16.518000
# Algeria2014                                                     22.832001
# Angola2014                                                      16.764000
# Bangladesh2014                                                   9.814000
# Benin2014                                                        4.163000
# ...                                                                   ...
# Vietnam2016                                                      6.763000
# West Bank and Gaza2016                                          33.678001
# Yemen, Rep.2016                                                 23.622000
# Zambia2016                                                      19.726999
# Zimbabwe2016                                                     5.927000
#
#                         Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate)
# Afghanistan2014                                                 17.570000
# Algeria2014                                                     25.559000
# Angola2014                                                      16.731001
# Bangladesh2014                                                  10.363000
# Benin2014                                                        4.664000
# ...                                                                   ...
# Vietnam2016                                                      6.750000
# West Bank and Gaza2016                                          38.237000
# Yemen, Rep.2016                                                 24.660999
# Zambia2016                                                      20.513000
# Zimbabwe2016                                                     6.825000
#
# [246 rows x 239 columns]

# %%
# Removing Outliers of 4 standard deviations or more away from the mean
df_trimmed = remove_outliers(df_median_filled,df_median_filled.columns,n_std = 4)
display(df_trimmed)

df_trimmed.to_csv("Processed Data/Data_trimmed.csv")
# Out:
#                   Adjusted net enrollment rate, primary (% of primary school age children)  \
# Afghanistan2014                                            90.02310
# Angola2014                                                 90.02310
# Benin2014                                                  96.36058
# Bolivia2014                                                87.94434
# Burkina Faso2014                                           68.30377
# ...                                                             ...
# Togo2016                                                   90.02310
# Uganda2016                                                 90.02310
# Uzbekistan2016                                             97.55430
# Vanuatu2016                                                90.02310
# Yemen, Rep.2016                                            84.39664
#
#                   Adjusted net enrollment rate, primary, female (% of primary school age children)  \
# Afghanistan2014                                            85.70568
# Angola2014                                                 85.70568
# Benin2014                                                  85.70568
# Bolivia2014                                                87.58961
# Burkina Faso2014                                           67.00632
# ...                                                             ...
# Togo2016                                                   85.70568
# Uganda2016                                                 85.70568
# Uzbekistan2016                                             85.70568
# Vanuatu2016                                                85.70568
# Yemen, Rep.2016                                            78.87941
#
#                   Adjusted net enrollment rate, primary, male (% of primary school age children)  \
# Afghanistan2014                                            88.30147
# Angola2014                                                 88.30147
# Benin2014                                                  88.30147
# Bolivia2014                                                88.28441
# Burkina Faso2014                                           69.55454
# ...                                                             ...
# Togo2016                                                   88.30147
# Uganda2016                                                 88.30147
# Uzbekistan2016                                             88.30147
# Vanuatu2016                                                88.30147
# Yemen, Rep.2016                                            89.70100
#
#                   Adolescents out of school (% of lower secondary school age)  \
# Afghanistan2014                                           19.433929
# Angola2014                                                19.433929
# Benin2014                                                 19.433929
# Bolivia2014                                                8.377710
# Burkina Faso2014                                          44.035610
# ...                                                             ...
# Togo2016                                                  19.433929
# Uganda2016                                                45.985901
# Uzbekistan2016                                             4.833740
# Vanuatu2016                                               19.433929
# Yemen, Rep.2016                                           28.443150
#
#                   Adolescents out of school, female (% of female lower secondary school age)  \
# Afghanistan2014                                           23.988251
# Angola2014                                                23.988251
# Benin2014                                                 23.988251
# Bolivia2014                                                8.631250
# Burkina Faso2014                                          44.668541
# ...                                                             ...
# Togo2016                                                  23.988251
# Uganda2016                                                46.446339
# Uzbekistan2016                                             5.289210
# Vanuatu2016                                               23.988251
# Yemen, Rep.2016                                           34.475868
#
#                   Adolescents out of school, male (% of male lower secondary school age)  \
# Afghanistan2014                                           22.195431
# Angola2014                                                22.195431
# Benin2014                                                 22.195431
# Bolivia2014                                                8.134330
# Burkina Faso2014                                          43.425480
# ...                                                             ...
# Togo2016                                                  22.195431
# Uganda2016                                                45.524830
# Uzbekistan2016                                             4.398410
# Vanuatu2016                                               22.195431
# Yemen, Rep.2016                                           22.633860
#
#                   Age dependency ratio (% of working-age population)  \
# Afghanistan2014                                           92.649143
# Angola2014                                                97.942205
# Benin2014                                                 86.811436
# Bolivia2014                                               65.210745
# Burkina Faso2014                                          93.014873
# ...                                                             ...
# Togo2016                                                  80.939722
# Uganda2016                                                98.315236
# Uzbekistan2016                                            48.214408
# Vanuatu2016                                               74.217254
# Yemen, Rep.2016                                           76.024870
#
#                   Age dependency ratio, old (% of working-age population)  \
# Afghanistan2014                                            4.722937
# Angola2014                                                 4.558697
# Benin2014                                                  6.030833
# Bolivia2014                                               10.942778
# Burkina Faso2014                                           4.677294
# ...                                                             ...
# Togo2016                                                   5.117856
# Uganda2016                                                 3.769529
# Uzbekistan2016                                             6.138487
# Vanuatu2016                                                6.454137
# Yemen, Rep.2016                                            4.973850
#
#                   Age dependency ratio, young (% of working-age population)  \
# Afghanistan2014                                           87.926206
# Angola2014                                                93.383508
# Benin2014                                                 80.780603
# Bolivia2014                                               54.267967
# Burkina Faso2014                                          88.337579
# ...                                                             ...
# Togo2016                                                  75.821866
# Uganda2016                                                94.545707
# Uzbekistan2016                                            42.075921
# Vanuatu2016                                               67.763117
# Yemen, Rep.2016                                           71.051020
#
#                   Antiretroviral therapy coverage (% of people living with HIV)  \
# Afghanistan2014                                                 4.0
# Angola2014                                                     22.0
# Benin2014                                                      41.0
# Bolivia2014                                                    18.0
# Burkina Faso2014                                               47.0
# ...                                                             ...
# Togo2016                                                       47.0
# Uganda2016                                                     65.0
# Uzbekistan2016                                                 39.0
# Vanuatu2016                                                    33.0
# Yemen, Rep.2016                                                24.0
#
#                   ...  Trade (% of GDP)  \
# Afghanistan2014   ...         61.969432
# Angola2014        ...         79.332923
# Benin2014         ...         65.268275
# Bolivia2014       ...         85.264470
# Burkina Faso2014  ...         58.823562
# ...               ...               ...
# Togo2016          ...         66.880569
# Uganda2016        ...         31.209362
# Uzbekistan2016    ...         29.192297
# Vanuatu2016       ...        109.543485
# Yemen, Rep.2016   ...         25.276643
#
#                   Unemployment, female (% of female labor force) (modeled ILO estimate)  \
# Afghanistan2014                                              14.152
# Angola2014                                                    7.754
# Benin2014                                                     2.366
# Bolivia2014                                                   2.878
# Burkina Faso2014                                              4.370
# ...                                                             ...
# Togo2016                                                      2.225
# Uganda2016                                                    2.459
# Uzbekistan2016                                                5.020
# Vanuatu2016                                                   1.542
# Yemen, Rep.2016                                              25.850
#
#                   Unemployment, female (% of female labor force) (national estimate)  \
# Afghanistan2014                                               10.11
# Angola2014                                                     9.10
# Benin2014                                                      5.61
# Bolivia2014                                                    2.85
# Burkina Faso2014                                               9.24
# ...                                                             ...
# Togo2016                                                       5.61
# Uganda2016                                                     5.61
# Uzbekistan2016                                                 4.97
# Vanuatu2016                                                    5.61
# Yemen, Rep.2016                                                5.61
#
#                   Unemployment, male (% of male labor force) (modeled ILO estimate)  \
# Afghanistan2014                                              10.469
# Angola2014                                                    6.999
# Benin2014                                                     1.906
# Bolivia2014                                                   1.373
# Burkina Faso2014                                              4.039
# ...                                                             ...
# Togo2016                                                      3.661
# Uganda2016                                                    1.397
# Uzbekistan2016                                                5.321
# Vanuatu2016                                                   1.957
# Yemen, Rep.2016                                              12.311
#
#                   Unemployment, male (% of male labor force) (national estimate)  \
# Afghanistan2014                                                7.20
# Angola2014                                                     9.96
# Benin2014                                                      4.83
# Bolivia2014                                                    1.36
# Burkina Faso2014                                               3.86
# ...                                                             ...
# Togo2016                                                       4.83
# Uganda2016                                                     4.83
# Uzbekistan2016                                                 5.33
# Vanuatu2016                                                    4.83
# Yemen, Rep.2016                                                4.83
#
#                   Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# Afghanistan2014                                              11.142
# Angola2014                                                    7.372
# Benin2014                                                     2.133
# Bolivia2014                                                   2.020
# Burkina Faso2014                                              4.188
# ...                                                             ...
# Togo2016                                                      2.966
# Uganda2016                                                    1.920
# Uzbekistan2016                                                5.200
# Vanuatu2016                                                   1.776
# Yemen, Rep.2016                                              13.433
#
#                   Unemployment, total (% of total labor force) (national estimate)  \
# Afghanistan2014                                                7.91
# Angola2014                                                     9.58
# Benin2014                                                      4.77
# Bolivia2014                                                    2.02
# Burkina Faso2014                                               6.48
# ...                                                             ...
# Togo2016                                                       4.77
# Uganda2016                                                     4.77
# Uzbekistan2016                                                 5.16
# Vanuatu2016                                                    4.77
# Yemen, Rep.2016                                                4.77
#
#                   Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate)  \
# Afghanistan2014                                           21.681000
# Angola2014                                                16.697001
# Benin2014                                                  5.078000
# Bolivia2014                                                7.061000
# Burkina Faso2014                                           7.415000
# ...                                                             ...
# Togo2016                                                   5.696000
# Uganda2016                                                 3.457000
# Uzbekistan2016                                            12.713000
# Vanuatu2016                                                4.362000
# Yemen, Rep.2016                                           34.591000
#
#                   Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate)  \
# Afghanistan2014                                              16.518
# Angola2014                                                   16.764
# Benin2014                                                     4.163
# Bolivia2014                                                   3.026
# Burkina Faso2014                                              6.610
# ...                                                             ...
# Togo2016                                                      7.997
# Uganda2016                                                    2.211
# Uzbekistan2016                                               12.102
# Vanuatu2016                                                   4.420
# Yemen, Rep.2016                                              23.622
#
#                   Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate)
# Afghanistan2014                                           17.570000
# Angola2014                                                16.731001
# Benin2014                                                  4.664000
# Bolivia2014                                                4.674000
# Burkina Faso2014                                           6.951000
# ...                                                             ...
# Togo2016                                                   6.724000
# Uganda2016                                                 2.822000
# Uzbekistan2016                                            12.320000
# Vanuatu2016                                                4.393000
# Yemen, Rep.2016                                           24.660999
#
# [153 rows x 239 columns]

# %%
# Creating DataFrame of R2 values of each feature against chosen target
target = "People using at least basic sanitation services (% of population)"
target_ls, features_ls = seperate_target_out(df_trimmed,target)
df_r2_target = r_value(df_trimmed,target_ls,features_ls)**2
display (df_r2_target)
# Out:
#                                                     People using at least basic sanitation services (% of population)
# Adjusted net enrollment rate, primary (% of pri...                                           0.090648
# Adjusted net enrollment rate, primary, female (...                                           0.087637
# Adjusted net enrollment rate, primary, male (% ...                                           0.043125
# Adolescents out of school (% of lower secondary...                                           0.219125
# Adolescents out of school, female (% of female ...                                           0.194294
# ...                                                                                               ...
# Unemployment, total (% of total labor force) (m...                                           0.106111
# Unemployment, total (% of total labor force) (n...                                           0.129183
# Unemployment, youth female (% of female labor f...                                           0.203704
# Unemployment, youth male (% of male labor force...                                           0.198043
# Unemployment, youth total (% of total labor for...                                           0.197011
#
# [238 rows x 1 columns]

# %% [markdown]
# ## ● Model
#
# ### o Discussion on the predictors or features

# %% [markdown]
# #### To find our 4 independent features from the set of 238 features, we will first find the features that correlate with the target.
# #### We set r^2 value >= 0.2 as meaning that the target is correlated with the feature.

# %%
# Finding ONLY the features that are correlated to the target with threshold of r^2 >= 0.2 (i.e correlation coefficient = 0.5)
df_chosen_features = find_related_features(df_r2_target,r2_threshold = 0.2)
display(df_chosen_features)
# Out:
#                                                     People using at least basic sanitation services (% of population)
# Adolescents out of school (% of lower secondary...                                           0.219125
# Age dependency ratio (% of working-age population)                                           0.507641
# Age dependency ratio, old (% of working-age pop...                                           0.294637
# Age dependency ratio, young (% of working-age p...                                           0.513447
# Domestic general government health expenditure ...                                           0.270962
# ...                                                                                               ...
# Labor force participation rate, total (% of tot...                                           0.218267
# Labor force, female (% of total labor force)                                                 0.233962
# Ratio of female to male labor force participati...                                           0.298546
# Renewable energy consumption (% of total final ...                                           0.466654
# Unemployment, youth female (% of female labor f...                                           0.203704
#
# [111 rows x 1 columns]

# %% [markdown]
# #### From these 111 features that are correlated to the target, we will now find which 4 of these features are independent.
#
# #### First, we will plot the correlation coefficient (r value) between each pair of the 111 features.

# %%
# Finding the r2 value between each feature, where r2 value is the square of the correlation coefficient
# Creating r2 matrix to see correlation between all 114 features
features_ls = list(df_chosen_features.index)
df_r2_features = r_value(df_trimmed,features_ls,features_ls)**2
display(df_r2_features)
df_r2_features.to_csv('Processed Data/R2_Comparison_Features.csv')
# Out:
#                                                     Adolescents out of school (% of lower secondary school age)  \
# Adolescents out of school (% of lower secondary...                                           1.000000
# Age dependency ratio (% of working-age population)                                           0.275289
# Age dependency ratio, old (% of working-age pop...                                           0.120663
# Age dependency ratio, young (% of working-age p...                                           0.272981
# Domestic general government health expenditure ...                                           0.112189
# ...                                                                                               ...
# Labor force participation rate, total (% of tot...                                           0.039052
# Labor force, female (% of total labor force)                                                 0.027637
# Ratio of female to male labor force participati...                                           0.025560
# Renewable energy consumption (% of total final ...                                           0.174731
# Unemployment, youth female (% of female labor f...                                           0.065192
#
#                                                     Age dependency ratio (% of working-age population)  \
# Adolescents out of school (% of lower secondary...                                           0.275289
# Age dependency ratio (% of working-age population)                                           1.000000
# Age dependency ratio, old (% of working-age pop...                                           0.443679
# Age dependency ratio, young (% of working-age p...                                           0.993676
# Domestic general government health expenditure ...                                           0.174998
# ...                                                                                               ...
# Labor force participation rate, total (% of tot...                                           0.076871
# Labor force, female (% of total labor force)                                                 0.114325
# Ratio of female to male labor force participati...                                           0.148266
# Renewable energy consumption (% of total final ...                                           0.357240
# Unemployment, youth female (% of female labor f...                                           0.119539
#
#                                                     Age dependency ratio, old (% of working-age population)  \
# Adolescents out of school (% of lower secondary...                                           0.120663
# Age dependency ratio (% of working-age population)                                           0.443679
# Age dependency ratio, old (% of working-age pop...                                           1.000000
# Age dependency ratio, young (% of working-age p...                                           0.522976
# Domestic general government health expenditure ...                                           0.273209
# ...                                                                                               ...
# Labor force participation rate, total (% of tot...                                           0.053820
# Labor force, female (% of total labor force)                                                 0.083126
# Ratio of female to male labor force participati...                                           0.142252
# Renewable energy consumption (% of total final ...                                           0.255285
# Unemployment, youth female (% of female labor f...                                           0.096318
#
#                                                     Age dependency ratio, young (% of working-age population)  \
# Adolescents out of school (% of lower secondary...                                           0.272981
# Age dependency ratio (% of working-age population)                                           0.993676
# Age dependency ratio, old (% of working-age pop...                                           0.522976
# Age dependency ratio, young (% of working-age p...                                           1.000000
# Domestic general government health expenditure ...                                           0.195706
# ...                                                                                               ...
# Labor force participation rate, total (% of tot...                                           0.078728
# Labor force, female (% of total labor force)                                                 0.117949
# Ratio of female to male labor force participati...                                           0.157090
# Renewable energy consumption (% of total final ...                                           0.367999
# Unemployment, youth female (% of female labor f...                                           0.124706
#
#                                                     Domestic general government health expenditure (% of GDP)  \
# Adolescents out of school (% of lower secondary...                                           0.112189
# Age dependency ratio (% of working-age population)                                           0.174998
# Age dependency ratio, old (% of working-age pop...                                           0.273209
# Age dependency ratio, young (% of working-age p...                                           0.195706
# Domestic general government health expenditure ...                                           1.000000
# ...                                                                                               ...
# Labor force participation rate, total (% of tot...                                           0.013861
# Labor force, female (% of total labor force)                                                 0.013972
# Ratio of female to male labor force participati...                                           0.027470
# Renewable energy consumption (% of total final ...                                           0.169740
# Unemployment, youth female (% of female labor f...                                           0.024060
#
#                                                     External health expenditure (% of current health expenditure)  \
# Adolescents out of school (% of lower secondary...                                           0.056382
# Age dependency ratio (% of working-age population)                                           0.227840
# Age dependency ratio, old (% of working-age pop...                                           0.175636
# Age dependency ratio, young (% of working-age p...                                           0.236224
# Domestic general government health expenditure ...                                           0.065350
# ...                                                                                               ...
# Labor force participation rate, total (% of tot...                                           0.214752
# Labor force, female (% of total labor force)                                                 0.231667
# Ratio of female to male labor force participati...                                           0.266971
# Renewable energy consumption (% of total final ...                                           0.251910
# Unemployment, youth female (% of female labor f...                                           0.075293
#
#                                                     Immunization, measles (% of children ages 12-23 months)  \
# Adolescents out of school (% of lower secondary...                                           0.047682
# Age dependency ratio (% of working-age population)                                           0.258716
# Age dependency ratio, old (% of working-age pop...                                           0.101281
# Age dependency ratio, young (% of working-age p...                                           0.255554
# Domestic general government health expenditure ...                                           0.228563
# ...                                                                                               ...
# Labor force participation rate, total (% of tot...                                           0.000023
# Labor force, female (% of total labor force)                                                 0.005453
# Ratio of female to male labor force participati...                                           0.019975
# Renewable energy consumption (% of total final ...                                           0.073487
# Unemployment, youth female (% of female labor f...                                           0.009884
#
#                                                     Individuals using the Internet (% of population)  \
# Adolescents out of school (% of lower secondary...                                          0.148841
# Age dependency ratio (% of working-age population)                                          0.426620
# Age dependency ratio, old (% of working-age pop...                                          0.338485
# Age dependency ratio, young (% of working-age p...                                          0.443193
# Domestic general government health expenditure ...                                          0.204626
# ...                                                                                              ...
# Labor force participation rate, total (% of tot...                                          0.182954
# Labor force, female (% of total labor force)                                                0.180600
# Ratio of female to male labor force participati...                                          0.221575
# Renewable energy consumption (% of total final ...                                          0.526975
# Unemployment, youth female (% of female labor f...                                          0.254928
#
#                                                     Lifetime risk of maternal death (%)  \
# Adolescents out of school (% of lower secondary...                             0.270704
# Age dependency ratio (% of working-age population)                             0.581394
# Age dependency ratio, old (% of working-age pop...                             0.260280
# Age dependency ratio, young (% of working-age p...                             0.577611
# Domestic general government health expenditure ...                             0.240703
# ...                                                                                 ...
# Labor force participation rate, total (% of tot...                             0.025557
# Labor force, female (% of total labor force)                                   0.058049
# Ratio of female to male labor force participati...                             0.066982
# Renewable energy consumption (% of total final ...                             0.264689
# Unemployment, youth female (% of female labor f...                             0.060622
#
#                                                     Lower secondary completion rate, female (% of relevant age group)  \
# Adolescents out of school (% of lower secondary...                                           0.382958
# Age dependency ratio (% of working-age population)                                           0.399592
# Age dependency ratio, old (% of working-age pop...                                           0.257894
# Age dependency ratio, young (% of working-age p...                                           0.408809
# Domestic general government health expenditure ...                                           0.175094
# ...                                                                                               ...
# Labor force participation rate, total (% of tot...                                           0.081058
# Labor force, female (% of total labor force)                                                 0.047983
# Ratio of female to male labor force participati...                                           0.060792
# Renewable energy consumption (% of total final ...                                           0.281211
# Unemployment, youth female (% of female labor f...                                           0.125356
#
#                                                     ...  \
# Adolescents out of school (% of lower secondary...  ...
# Age dependency ratio (% of working-age population)  ...
# Age dependency ratio, old (% of working-age pop...  ...
# Age dependency ratio, young (% of working-age p...  ...
# Domestic general government health expenditure ...  ...
# ...                                                 ...
# Labor force participation rate, total (% of tot...  ...
# Labor force, female (% of total labor force)        ...
# Ratio of female to male labor force participati...  ...
# Renewable energy consumption (% of total final ...  ...
# Unemployment, youth female (% of female labor f...  ...
#
#                                                     Access to electricity, urban (% of urban population)  \
# Adolescents out of school (% of lower secondary...                                           0.116754
# Age dependency ratio (% of working-age population)                                           0.498329
# Age dependency ratio, old (% of working-age pop...                                           0.249205
# Age dependency ratio, young (% of working-age p...                                           0.499411
# Domestic general government health expenditure ...                                           0.082943
# ...                                                                                               ...
# Labor force participation rate, total (% of tot...                                           0.178557
# Labor force, female (% of total labor force)                                                 0.222651
# Ratio of female to male labor force participati...                                           0.256145
# Renewable energy consumption (% of total final ...                                           0.355397
# Unemployment, youth female (% of female labor f...                                           0.118969
#
#                                                     Agriculture, forestry, and fishing, value added (% of GDP)  \
# Adolescents out of school (% of lower secondary...                                           0.110781
# Age dependency ratio (% of working-age population)                                           0.171770
# Age dependency ratio, old (% of working-age pop...                                           0.215696
# Age dependency ratio, young (% of working-age p...                                           0.187904
# Domestic general government health expenditure ...                                           0.166606
# ...                                                                                               ...
# Labor force participation rate, total (% of tot...                                           0.117028
# Labor force, female (% of total labor force)                                                 0.084713
# Ratio of female to male labor force participati...                                           0.081731
# Renewable energy consumption (% of total final ...                                           0.284938
# Unemployment, youth female (% of female labor f...                                           0.158748
#
#                                                     Labor force participation rate for ages 15-24, female (%) (modeled ILO estimate)  \
# Adolescents out of school (% of lower secondary...                                           0.050658
# Age dependency ratio (% of working-age population)                                           0.103914
# Age dependency ratio, old (% of working-age pop...                                           0.071534
# Age dependency ratio, young (% of working-age p...                                           0.106296
# Domestic general government health expenditure ...                                           0.022303
# ...                                                                                               ...
# Labor force participation rate, total (% of tot...                                           0.896980
# Labor force, female (% of total labor force)                                                 0.643617
# Ratio of female to male labor force participati...                                           0.665328
# Renewable energy consumption (% of total final ...                                           0.433020
# Unemployment, youth female (% of female labor f...                                           0.429080
#
#                                                     Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)  \
# Adolescents out of school (% of lower secondary...                                           0.036340
# Age dependency ratio (% of working-age population)                                           0.119525
# Age dependency ratio, old (% of working-age pop...                                           0.097716
# Age dependency ratio, young (% of working-age p...                                           0.124430
# Domestic general government health expenditure ...                                           0.018939
# ...                                                                                               ...
# Labor force participation rate, total (% of tot...                                           0.920100
# Labor force, female (% of total labor force)                                                 0.839071
# Ratio of female to male labor force participati...                                           0.871613
# Renewable energy consumption (% of total final ...                                           0.491983
# Unemployment, youth female (% of female labor f...                                           0.440660
#
#                                                     Labor force participation rate, female (% of female population ages 15-64) (modeled ILO estimate)  \
# Adolescents out of school (% of lower secondary...                                           0.038928
# Age dependency ratio (% of working-age population)                                           0.109390
# Age dependency ratio, old (% of working-age pop...                                           0.088279
# Age dependency ratio, young (% of working-age p...                                           0.113718
# Domestic general government health expenditure ...                                           0.014694
# ...                                                                                               ...
# Labor force participation rate, total (% of tot...                                           0.916102
# Labor force, female (% of total labor force)                                                 0.837618
# Ratio of female to male labor force participati...                                           0.854881
# Renewable energy consumption (% of total final ...                                           0.482923
# Unemployment, youth female (% of female labor f...                                           0.451456
#
#                                                     Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate)  \
# Adolescents out of school (% of lower secondary...                                           0.039052
# Age dependency ratio (% of working-age population)                                           0.076871
# Age dependency ratio, old (% of working-age pop...                                           0.053820
# Age dependency ratio, young (% of working-age p...                                           0.078728
# Domestic general government health expenditure ...                                           0.013861
# ...                                                                                               ...
# Labor force participation rate, total (% of tot...                                           1.000000
# Labor force, female (% of total labor force)                                                 0.613063
# Ratio of female to male labor force participati...                                           0.637888
# Renewable energy consumption (% of total final ...                                           0.396896
# Unemployment, youth female (% of female labor f...                                           0.377563
#
#                                                     Labor force, female (% of total labor force)  \
# Adolescents out of school (% of lower secondary...                                      0.027637
# Age dependency ratio (% of working-age population)                                      0.114325
# Age dependency ratio, old (% of working-age pop...                                      0.083126
# Age dependency ratio, young (% of working-age p...                                      0.117949
# Domestic general government health expenditure ...                                      0.013972
# ...                                                                                          ...
# Labor force participation rate, total (% of tot...                                      0.613063
# Labor force, female (% of total labor force)                                            1.000000
# Ratio of female to male labor force participati...                                      0.960128
# Renewable energy consumption (% of total final ...                                      0.501428
# Unemployment, youth female (% of female labor f...                                      0.448558
#
#                                                     Ratio of female to male labor force participation rate (%) (modeled ILO estimate)  \
# Adolescents out of school (% of lower secondary...                                           0.025560
# Age dependency ratio (% of working-age population)                                           0.148266
# Age dependency ratio, old (% of working-age pop...                                           0.142252
# Age dependency ratio, young (% of working-age p...                                           0.157090
# Domestic general government health expenditure ...                                           0.027470
# ...                                                                                               ...
# Labor force participation rate, total (% of tot...                                           0.637888
# Labor force, female (% of total labor force)                                                 0.960128
# Ratio of female to male labor force participati...                                           1.000000
# Renewable energy consumption (% of total final ...                                           0.512813
# Unemployment, youth female (% of female labor f...                                           0.439833
#
#                                                     Renewable energy consumption (% of total final energy consumption)  \
# Adolescents out of school (% of lower secondary...                                           0.174731
# Age dependency ratio (% of working-age population)                                           0.357240
# Age dependency ratio, old (% of working-age pop...                                           0.255285
# Age dependency ratio, young (% of working-age p...                                           0.367999
# Domestic general government health expenditure ...                                           0.169740
# ...                                                                                               ...
# Labor force participation rate, total (% of tot...                                           0.396896
# Labor force, female (% of total labor force)                                                 0.501428
# Ratio of female to male labor force participati...                                           0.512813
# Renewable energy consumption (% of total final ...                                           1.000000
# Unemployment, youth female (% of female labor f...                                           0.326652
#
#                                                     Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate)
# Adolescents out of school (% of lower secondary...                                           0.065192
# Age dependency ratio (% of working-age population)                                           0.119539
# Age dependency ratio, old (% of working-age pop...                                           0.096318
# Age dependency ratio, young (% of working-age p...                                           0.124706
# Domestic general government health expenditure ...                                           0.024060
# ...                                                                                               ...
# Labor force participation rate, total (% of tot...                                           0.377563
# Labor force, female (% of total labor force)                                                 0.448558
# Ratio of female to male labor force participati...                                           0.439833
# Renewable energy consumption (% of total final ...                                           0.326652
# Unemployment, youth female (% of female labor f...                                           1.000000
#
# [111 rows x 111 columns]

# %% [markdown]
# #### Producing the csv onto Excel, we checked for intersections between features where the R2 < 0.1.
# #### R2 < 0.1 means that the 2 features do not correlate or correlate very weakly.
# ##### The intersections where R2 < 0.1 are labelled in red using Excel's conditional highlighting feature.

# %% [markdown]
# <img src="Images/R2_Feature_Comparison.JPG"
#      alt="Image"
#      style="float: left; margin-right: 10px;" />

# %% [markdown]
# #### To proceed, we first started with choosing 'Primary completion rate, total (% of relevant age group)' as one of our desired features.
# #### Starting from the row in yellow, looking across all columns, we highlight any vertical column where its intersection with the yellow row is red.
# #### From this, you can see that across the yellow row, there are 4 unique vertical columns intersecting it.
# #### We disregard the yellow - yellow intersection because that's simply the feature against itself.

# %% [markdown]
# <img src="Images/R2_Feature_Comparison_4.JPG"
#      alt="Image"
#      style="float: left; margin-right: 10px;" />

# %% [markdown]
# #### We only selected the features that include a portion of the total population rather than a subset of the population.
# #### For instance, 'People practicing open defecation (% of population)' vs 'People practicing open defecation, rural (% of rural population)'

# %% [markdown]
# #### After isolating the 5 features, to ensure independence between features, we did an Excel comparison of R2 values between them.

# %% [markdown]
# <img src="Images/R2_Feature_Comparison_5.JPG"
#      alt="Image"
#      style="float: left; margin-right: 10px;" />

# %% [markdown]
# #### As seen from above, yellow feature has low correlation with 4 other features.
# #### It can also be seen that green feature shows correlation with 2 other features, which means that the green feature has to be discarded.
# #### After discarding the green feature, we will obtain 4 features that are independent from one another.

# %% [markdown]
# <img src="Images/R2_Feature_Comparison_6.JPG"
#      alt="Image"
#      style="float: left; margin-right: 10px;" />

# %% [markdown]
# # From above, we can see that each feature is now not correlated to each of the other 4 factors.
#
# #### Hence, from a total of 238 features, we narrowed it down to 111 features by finding the features that are solely finding those that are correlated to the target.
# #### Next, we further narrowed 111 features to 5 selected features by using one of the 111 features as a reference.
# #### Finally, we narrowed down from 5 features to 4 features after ensuring the selected features are independent.

# %%
# This is the final data set we will be using for the remainder of the code
df_final = df_trimmed[["Tuberculosis case detection rate (%, all forms)", "Labor force, female (% of total labor force)", "People practicing open defecation (% of population)", "Primary completion rate, total (% of relevant age group)", "People using at least basic sanitation services (% of population)"]]
df_final
# Out:
#                   Tuberculosis case detection rate (%, all forms)  \
# Afghanistan2014                                              50.0
# Angola2014                                                   54.0
# Benin2014                                                    61.0
# Bolivia2014                                                  63.0
# Burkina Faso2014                                             59.0
# ...                                                           ...
# Togo2016                                                     80.0
# Uganda2016                                                   54.0
# Uzbekistan2016                                               67.0
# Vanuatu2016                                                  64.0
# Yemen, Rep.2016                                              72.0
#
#                   Labor force, female (% of total labor force)  \
# Afghanistan2014                                      18.275341
# Angola2014                                           49.363705
# Benin2014                                            49.444921
# Bolivia2014                                          42.971425
# Burkina Faso2014                                     44.990145
# ...                                                        ...
# Togo2016                                             48.444742
# Uganda2016                                           49.220145
# Uzbekistan2016                                       40.132749
# Vanuatu2016                                          43.608041
# Yemen, Rep.2016                                       8.283121
#
#                   People practicing open defecation (% of population)  \
# Afghanistan2014                                           15.248276
# Angola2014                                                23.843090
# Benin2014                                                 56.206296
# Bolivia2014                                               16.388945
# Burkina Faso2014                                          49.238977
# ...                                                             ...
# Togo2016                                                  47.767991
# Uganda2016                                                 6.463662
# Uzbekistan2016                                             0.000000
# Vanuatu2016                                                0.581828
# Yemen, Rep.2016                                           14.209447
#
#                   Primary completion rate, total (% of relevant age group)  \
# Afghanistan2014                                           88.059189
# Angola2014                                                88.059189
# Benin2014                                                 79.454399
# Bolivia2014                                               90.711960
# Burkina Faso2014                                          60.849499
# ...                                                             ...
# Togo2016                                                  92.715149
# Uganda2016                                                54.743011
# Uzbekistan2016                                            96.819221
# Vanuatu2016                                               88.059189
# Yemen, Rep.2016                                           72.300392
#
#                   People using at least basic sanitation services (% of population)
# Afghanistan2014                                           41.060966
# Angola2014                                                46.117029
# Benin2014                                                 14.365499
# Bolivia2014                                               54.944525
# Burkina Faso2014                                          19.360444
# ...                                                             ...
# Togo2016                                                  16.714317
# Uganda2016                                                19.253691
# Uzbekistan2016                                           100.000000
# Vanuatu2016                                               53.148221
# Yemen, Rep.2016                                           52.097813
#
# [153 rows x 5 columns]

# %% [markdown]
# #### This is a plot of each feature against each other and the target.
# #### The target is on the y-axis of the bottom row below, and there is a visible pattern of each feature to the target.
# #### The plot of each feature to another also shows little discernible pattern which validates the above findings.

# %%
sns.pairplot(df_final, height=4)

# %% [markdown]
# ### To conclude the above part, the features we have decided on are :
# #### 1. Primary completion rate, total (% of relevant age group)
# #### 2. People practicing open defecation (% of population)
# #### 3. Tuberculosis case detection rate (%, all forms)
# #### 4. Labor force, female (% of total labor force)### o Code and discussion on building the model

# %% [markdown]
# ### o Code and discussion on building the model

# %% [markdown]
# ### Our Hypotheses :

# %% [markdown]
# <img src="Images/Hypotheses.JPG"
#      alt="Image"
#      style="float: left; margin-right: 10px;" />

# %% [markdown]
# #### We will be first starting with linear as our first model, followed by quadratic, followed by cubic on the same training set.

# %% [markdown]
# ### In order to choose the optimal number of iterations to run gradient descent, we will :
# #### 1. Modify cohort gradient descent to store beta vectors instead of cost values
# #### 2. WIth the list of beta vectors, we can find their respective r2 scores and plot them
# #### 3. From the plots, we can visualise the point where model begins overfitting (r2 values begin to drop)
# #### 4. Find the number of iterations before overfitting occurs by finding the highest r2 value
# #### 5. Use optimal number of iterations to get final beta vector for that particular hypothesis

# %%
# Modified Cohort Functions

# Takes in a DataFrame, columns of features, columns of targets and returns DataFrame of features and targets.
def get_features_targets(df, feature_names, target_names):
    df_feature = df[feature_names]
    df_target = df[target_names]
    return df_feature, df_target

# Matrix multiplication of your feature matrix and beta vectors
def calc_linear(X, beta):
    return np.matmul(X, beta)

# Gives sum of square errors between predicted values (X*b) and actual values(y)
def compute_cost(X, y, beta):
    # m is number of data points, 
    J = 0
    predicted_value = calc_linear(X, beta) # y hat vector
    error = predicted_value - y # (y hat - y) vector
    # matmul is the sum over the squares of the two vectors
    error_sq = np.matmul(error.T, error) # y hat - y - transposed(mult(y hat, y))
    # [[error_sq]] is in this format
    J = 1/(2*X.shape[0]) * error_sq
    return J[0][0]

# First converts df_feature to Numpy array then adds a column of 1s as the 1st column of df_feature
def prepare_feature(df_feature):
    cols = len(df_feature.columns)
    df_feature = df_feature.to_numpy().reshape(-1, cols) # -1 is to auto set rows/cols
    X = np.concatenate((np.ones((df_feature.shape[0], 1)), df_feature), axis = 1)
    return X

# First converts df_target to Numpy array
def prepare_target(df_target):
    return df_target.to_numpy().reshape(-1, len(df_target.columns))

# Performs gradient descent algorithm for num_iters and returns the stored cost values after each iteration
# Returns final beta vector
def gradient_descent(X, y, beta, alpha, num_iters):
    m = X.shape[0] # no. of data points in training set
    
    beta_storage = []
    
    # Loop through the gradient descent
    for i in range(num_iters):
        # Store current beta value
        beta_storage.append(beta.copy()) # Creates a shallow copy of beta, else it only stores reference to same beta object
        
        derivative_error_func = np.matmul(X.T, (calc_linear(X, beta) - y)) # [[dj/db0], [dj/db1]]
        # update beta
        beta -= alpha * (1/m) * derivative_error_func # [[b0], [b1]]
    
    # To store final beta value
    beta_storage.append(beta)
    return beta, beta_storage

# Computes predicted values matrix using df_feature matrix and beta column vector
def predict(df_feature, beta):
    X = prepare_feature(normalize_z(df_feature))
    return calc_linear(X, beta) # return a column of predicted values

# Splits data into a train set, validation set and test set
def split_data_with_validation(df_feature, df_target, random_state=None, validation_size=0.2, test_size=0.3): 
    np.random.seed(random_state) 
    indexes = df_feature.index # Returns a RangeIndex object that contains all indexes of df_feature
    j = int(validation_size* len(indexes)) # Size of validation set
    k = int(test_size* len(indexes)) # Size of test set
     
    test_index = set(np.random.choice(indexes, k, replace = False)) # Creates a set by randomly choosing k indices from indexes
    balance_index = set(indexes) - set(test_index) # Removes all the randomly chosen indexes used for test set
    validation_index = set(np.random.choice(list(balance_index), j, replace = False)) # Creates validation indexes
    train_index = balance_index - validation_index # Finds leftover indices to be used as training set indices
     
    df_feature_train = df_feature.loc[train_index, :] 
    df_feature_test = df_feature.loc[test_index, :] 
    df_target_train = df_target.loc[train_index, :] 
    df_target_test = df_target.loc[test_index, :] 
    df_feature_validation = df_feature.loc[validation_index, :] 
    df_target_validation = df_target.loc[validation_index, :] 
     
    return df_feature_train, df_feature_test, df_target_train, df_target_test, df_feature_validation, df_target_validation

# Calculates r2 score between actual and predicted values
def r2_score(y, ypred):
    ymean = np.mean(y) # mean from actual target
    mean_diff = y - ymean
    error = y - ypred
    
    #denominator
    ss_tot = np.matmul(mean_diff.T, mean_diff) # sum square of y-ymean
    
    # numerator
    ss_res = np.matmul(error.T, error) # sum sqaured of y-ypred
    
    r_2 = 1 - (ss_res/ss_tot)
    
    return r_2[0][0]

# Normalises values in the DataFrame
def normalize_z(df):
    dfout = df.copy()
    dfout = (dfout-dfout.mean(axis=0))/(dfout.std(axis=0))
    return dfout

# Calculation of MSE Score
def mse_score(y_actual, ypred):
    summ = 0
    n = len(y_actual)
    for i in range(0,n):  
        summ += ( y_actual[i] - ypred[i] )**2  
    MSE = summ/n  
    return MSE[0]

# %% [markdown]
# # Linear Model

# %%
df_feature, df_target = get_features_targets(df_final, ["Tuberculosis case detection rate (%, all forms)", "Labor force, female (% of total labor force)", "People practicing open defecation (% of population)", "Primary completion rate, total (% of relevant age group)"], ["People using at least basic sanitation services (% of population)"]) 

# split the data into training and test data sets
df_feature_train, df_feature_test, df_target_train, df_target_test, df_feature_validation, df_target_validation = split_data_with_validation(df_feature, df_target, random_state=100, validation_size=0.2, test_size=0.3)

# normalize the train set feature using z normalization
df_feature_train_z = normalize_z(df_feature_train)

# repare the feature matrix, add 1 to the second dimension
X = prepare_feature(df_feature_train_z)
target = prepare_target(df_target_train)

iterations = 1500
alpha = 0.01
beta = np.zeros((5,1)) # [[0], [0]] 5 rows 1 col

# call the gradient_descent function which now stores beta values instead of cost values
beta, beta_storage = gradient_descent(X, target, beta, alpha, iterations)

# prepare the validation set targets
target = prepare_target(df_target_validation)

# %%
# Creating list of r2 values for the beta value from each iteration of gradient descent
r2_scores_w_iters = []
for beta_val in beta_storage:
    pred = predict(df_feature_validation, beta_val) # a vector of predicted values using trained beta
    r2 = r2_score(target, pred)
    r2_scores_w_iters.append(r2)

# %%
plt.plot(r2_scores_w_iters)

# %% [markdown]
# #### Looking at above plot, we observe an increase followed by a dip in r2 score at around 200-300 iterations for this linear model
# #### The below code proceeds to find the optimal number of iterations that gives the greatest r2

# %%
index_of_highest_r = r2_scores_w_iters.index(max(r2_scores_w_iters))
print(index_of_highest_r, r2_scores_w_iters[index_of_highest_r])
# Out:
# 1040 0.6753845948621251

# %% [markdown]
# #### From this, we observed that by using the cohort's number of iterations, the resulting beta vectors result in an overfitted model. Instead, we should reduce the number of iterations for that model to 250 and use the beta vector at that particular iteration of gradient descent.

# %%
# Final beta values for Linear Model
beta_linear_final = beta_storage[index_of_highest_r]
r2_linear_final = r2_scores_w_iters[index_of_highest_r]
print(f'Final Beta Value for Linear Model : \n{beta_linear_final} ')
# Out:
# Final Beta Value for Linear Model :
# [[ 45.92015582]
#  [  8.87767902]
#  [ -6.80542726]
#  [-11.44708655]
#  [  8.22061869]]

# %% [markdown]
# #### MSE Score for Linear Model

# %%
prediction_with_final_beta = predict(df_feature_validation, beta_linear_final)
mse_linear = mse_score(target, prediction_with_final_beta)
print(mse_linear)
# Out:
# 253.25481529204777

# %% [markdown]
# ### We will proceed with the same methodology with the remaining 2 hypotheses.

# %% [markdown]
# # Quadratic Model

# %%
# Adding Quadratic Features to df_final which is the square of each of our features
df_final["Tuberculosis case detection rate (%, all forms)^2"] = df_final["Tuberculosis case detection rate (%, all forms)"]**2
df_final["Labor force, female (% of total labor force)^2"] = df_final["Labor force, female (% of total labor force)"]**2
df_final["People practicing open defecation (% of population)^2"] = df_final["People practicing open defecation (% of population)"]**2
df_final["Primary completion rate, total (% of relevant age group)^2"] = df_final["Primary completion rate, total (% of relevant age group)"]**2
# Out:
# <ipython-input-19-da208d567efb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["Tuberculosis case detection rate (%, all forms)^2"] = df_final["Tuberculosis case detection rate (%, all forms)"]**2
# <ipython-input-19-da208d567efb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["Labor force, female (% of total labor force)^2"] = df_final["Labor force, female (% of total labor force)"]**2
# <ipython-input-19-da208d567efb>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["People practicing open defecation (% of population)^2"] = df_final["People practicing open defecation (% of population)"]**2
# <ipython-input-19-da208d567efb>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["Primary completion rate, total (% of relevant age group)^2"] = df_final["Primary completion rate, total (% of relevant age group)"]**2

# %%
df_feature, df_target = get_features_targets(df_final, ["Tuberculosis case detection rate (%, all forms)", "Labor force, female (% of total labor force)", "People practicing open defecation (% of population)", "Primary completion rate, total (% of relevant age group)", "Tuberculosis case detection rate (%, all forms)^2", "Labor force, female (% of total labor force)^2", "People practicing open defecation (% of population)^2", "Primary completion rate, total (% of relevant age group)^2"], ["People using at least basic sanitation services (% of population)"]) # , "Newborns protected against tetanus (%)"

# split the data into training and test data sets
df_feature_train, df_feature_test, df_target_train, df_target_test, df_feature_validation, df_target_validation = split_data_with_validation(df_feature, df_target, random_state=100, validation_size=0.2, test_size=0.3)

# normalize the train set feature using z normalization
df_feature_train_z = normalize_z(df_feature_train)

# prepare the feature matrix, add 1 to the second dimension
X = prepare_feature(df_feature_train_z)
target = prepare_target(df_target_train)

iterations = 500000
alpha = 0.01
beta = np.zeros((9,1)) # [[0], [0]] 9 rows 1 col

# call the gradient_descent function which now stores beta values instead of cost values
beta, beta_storage = gradient_descent(X, target, beta, alpha, iterations)

# prepare the validation set targets
target = prepare_target(df_target_validation)

# %%
# Creating list of r2 values for the beta value from each iteration of gradient descent
r2_scores_w_iters = []
for beta_val in beta_storage:
    pred = predict(df_feature_validation, beta_val) # a vector of predicted values using trained beta
    r2 = r2_score(target, pred)
    r2_scores_w_iters.append(r2)

# %%
plt.plot(r2_scores_w_iters)

# %% [markdown]
# #### For the quadratic model, it can be observed that the optimal number of iterations is 385010 which gives the highest r2 value.

# %%
index_of_highest_r = r2_scores_w_iters.index(max(r2_scores_w_iters))
print(index_of_highest_r, r2_scores_w_iters[index_of_highest_r])
# Out:
# 2267 0.6868368210660818

# %%
# Final beta values for Quadratic Model
beta_quadratic_final = beta_storage[index_of_highest_r]
r2_quadratic_final = r2_scores_w_iters[index_of_highest_r]
print(f'Final Beta Value for Quadratic Model : \n{beta_quadratic_final} ')
# Out:
# Final Beta Value for Quadratic Model :
# [[ 45.92148204]
#  [  2.5468003 ]
#  [  4.83867084]
#  [-16.61825297]
#  [  0.25650309]
#  [  5.61311525]
#  [-12.20693043]
#  [  5.6282222 ]
#  [  7.6939284 ]]

# %% [markdown]
# ### MSE Score for Quadratic Model

# %%
prediction_with_final_beta = predict(df_feature_validation, beta_quadratic_final)
mse_quadratic = mse_score(target, prediction_with_final_beta)
print(mse_quadratic)
# Out:
# 244.32014556885972

# %% [markdown]
# # Cubic Model

# %%
# Adding Cubic Features to df_final which is the cube of each of our features
df_final["Tuberculosis case detection rate (%, all forms)^3"] = df_final["Tuberculosis case detection rate (%, all forms)"]**3
df_final["Labor force, female (% of total labor force)^3"] = df_final["Labor force, female (% of total labor force)"]**3
df_final["People practicing open defecation (% of population)^3"] = df_final["People practicing open defecation (% of population)"]**3
df_final["Primary completion rate, total (% of relevant age group)^3"] = df_final["Primary completion rate, total (% of relevant age group)"]**3
# Out:
# <ipython-input-26-834017d1d9ed>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["Tuberculosis case detection rate (%, all forms)^3"] = df_final["Tuberculosis case detection rate (%, all forms)"]**3
# <ipython-input-26-834017d1d9ed>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["Labor force, female (% of total labor force)^3"] = df_final["Labor force, female (% of total labor force)"]**3
# <ipython-input-26-834017d1d9ed>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["People practicing open defecation (% of population)^3"] = df_final["People practicing open defecation (% of population)"]**3
# <ipython-input-26-834017d1d9ed>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["Primary completion rate, total (% of relevant age group)^3"] = df_final["Primary completion rate, total (% of relevant age group)"]**3

# %%
df_feature, df_target = get_features_targets(df_final, ["Tuberculosis case detection rate (%, all forms)", "Labor force, female (% of total labor force)", "People practicing open defecation (% of population)", "Primary completion rate, total (% of relevant age group)", "Tuberculosis case detection rate (%, all forms)^2", "Labor force, female (% of total labor force)^2", "People practicing open defecation (% of population)^2", "Primary completion rate, total (% of relevant age group)^2", "Tuberculosis case detection rate (%, all forms)^3", "Labor force, female (% of total labor force)^3", "People practicing open defecation (% of population)^3", "Primary completion rate, total (% of relevant age group)^3"], ["People using at least basic sanitation services (% of population)"]) # , "Newborns protected against tetanus (%)"

# split the data into training and test data sets
df_feature_train, df_feature_test, df_target_train, df_target_test, df_feature_validation, df_target_validation = split_data_with_validation(df_feature, df_target, random_state=100, validation_size=0.2, test_size=0.3)

# normalize the train set feature using z normalization
df_feature_train_z = normalize_z(df_feature_train)

# prepare the feature matrix, add 1 to the second dimension
X = prepare_feature(df_feature_train_z)
target = prepare_target(df_target_train)

iterations = 1000000
alpha = 0.01
beta = np.zeros((13,1)) # [[0], [0]] 13 rows 1 col

# call the gradient_descent function which now stores beta values instead of cost values
beta, beta_storage = gradient_descent(X, target, beta, alpha, iterations)

# prepare the validation set targets
target = prepare_target(df_target_validation)

# %%
# Creating list of r2 values for the beta value from each iteration of gradient descent
r2_scores_w_iters = []
for beta_val in beta_storage:
    pred = predict(df_feature_validation, beta_val) # a vector of predicted values using trained beta
    r2 = r2_score(target, pred)
    r2_scores_w_iters.append(r2)

# %%
plt.plot(r2_scores_w_iters)

# %% [markdown]
# #### For the cubic model, it can be observed that the optimal number of iterations is 726487 which gives the highest r2 value.

# %%
index_of_highest_r = r2_scores_w_iters.index(max(r2_scores_w_iters))
print(index_of_highest_r, r2_scores_w_iters[index_of_highest_r])
# Out:
# 919 0.6798695356234199

# %%
# Final beta values for Cubic Model
beta_cubic_final = beta_storage[index_of_highest_r]
r2_cubic_final = r2_scores_w_iters[index_of_highest_r]
print(f'Final Beta Value for Cubic Model : \n{beta_cubic_final} ')
# Out:
# Final Beta Value for Cubic Model :
# [[ 45.91700739]
#  [  2.53214402]
#  [  2.88241577]
#  [-11.87354779]
#  [  0.34189493]
#  [  3.01383015]
#  [ -3.09049916]
#  [ -0.69371903]
#  [  2.809086  ]
#  [  2.93429399]
#  [ -7.51534905]
#  [  1.906168  ]
#  [  4.87432683]]

# %% [markdown]
# ### MSE Score for Cubic Model

# %%
prediction_with_final_beta = predict(df_feature_validation, beta_cubic_final)
mse_cubic = mse_score(target, prediction_with_final_beta)
print(mse_cubic)
# Out:
# 249.75580438215263

# %% [markdown]
# # Choosing the Best Model based on MSE and R2

# %%
sns.barplot(x=["Linear", "Quadratic", "Cubic"], y = [mse_linear, mse_quadratic, mse_cubic])
plt.ylabel("MSE")
# Out:
# Text(0, 0.5, 'MSE')

# %%
sns.barplot(x=["Linear", "Quadratic", "Cubic"], y = [r2_linear_final, r2_quadratic_final, r2_cubic_final])
plt.ylabel("R2 Score")
# Out:
# Text(0, 0.5, 'R2 Score')

# %% [markdown]
# ### Finally, we choose the cubic model because it has the lowest MSE compared to the other models we have tried previously.

# %% [markdown]
# ## ● Model Evaluation
#
# ### o Discussion on the chosen metric to evaluate your final model, how that model compares with your earlier attempts, any mathematical details, and all resources consulted

# %% [markdown]
# ### We will be using Root Mean Squared Error (RMSE) as our final metric to evaluate our final model. The RMSE has units of % and its scale ranges from 0 to 100 as our target refers to the 'People using at least basic sanitation services (% of population)'. Hence, our predicted values should be within the range where lower indicates that the uncertainty of prediction is less.

# %% [markdown]
# ### We will first be reporting the R2 score of our model using the test set.

# %% [markdown]
# ### o Code and results of the metric on your test data set

# %%
# Calculation of r2 value with test set

# normalize the test feature set feature using z normalization
df_feature_test_z = normalize_z(df_feature_test)

# prepare the feature matrix, add 1 to the second dimension
X = prepare_feature(df_feature_test_z)
target = prepare_target(df_target_test)

pred = predict(df_feature_test, beta_cubic_final) # a vector of predicted values using trained beta
r2 = r2_score(target, pred)
print(r2)
# Out:
# 0.7165054192961621

# %%
plt.scatter(target,pred)

# %%
# Calculation of RMSE
import math

prediction_with_cubic = predict(df_feature_test, beta_cubic_final)
mse_cubic = mse_score(target, prediction_with_cubic)
rmse = math.sqrt(mse_cubic)
print(rmse)
# Out:
# 13.814505195438374

# %% [markdown]
# ### To conclude, our model has an average RMSE of 14%.
